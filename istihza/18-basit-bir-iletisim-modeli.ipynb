# %% [markdown]
# #  8 bitlik bir sistem

# %%
for i in range(10):
    print(bin(i)[2:].zfill(8))
# Out:
# 00000000
# 00000001
# 00000010
# 00000011
# 00000100
# 00000101
# 00000110
# 00000111
# 00001000
# 00001001

# %%
for i in range(256):
    print(bin(i)[2:], i.bit_length(), sep="\t")
# Out:
# 0	0
# 1	1
# 10	2
# 11	2
# 100	3
# 101	3
# 110	3
# 111	3
# 1000	4
# 1001	4
# 1010	4
# 1011	4
# 1100	4
# 1101	4
# 1110	4
# 1111	4
# 10000	5
# 10001	5
# 10010	5
# 10011	5
# 10100	5
# 10101	5
# 10110	5
# 10111	5
# 11000	5
# 11001	5
# 11010	5
# 11011	5
# 11100	5
# 11101	5
# 11110	5
# 11111	5
# 100000	6
# 100001	6
# 100010	6
# 100011	6
# 100100	6
# 100101	6
# 100110	6
# 100111	6
# 101000	6
# 101001	6
# 101010	6
# 101011	6
# 101100	6
# 101101	6
# 101110	6
# 101111	6
# 110000	6
# 110001	6
# 110010	6
# 110011	6
# 110100	6
# 110101	6
# 110110	6
# 110111	6
# 111000	6
# 111001	6
# 111010	6
# 111011	6
# 111100	6
# 111101	6
# 111110	6
# 111111	6
# 1000000	7
# 1000001	7
# 1000010	7
# 1000011	7
# 1000100	7
# 1000101	7
# 1000110	7
# 1000111	7
# 1001000	7
# 1001001	7
# 1001010	7
# 1001011	7
# 1001100	7
# 1001101	7
# 1001110	7
# 1001111	7
# 1010000	7
# 1010001	7
# 1010010	7
# 1010011	7
# 1010100	7
# 1010101	7
# 1010110	7
# 1010111	7
# 1011000	7
# 1011001	7
# 1011010	7
# 1011011	7
# 1011100	7
# ...

# %%
bin(255)[2:]
# Out:
# '11111111'

# %%
print(bin(256)[2:])
(256).bit_length()
# Out:
# 100000000
# 9

# %% [markdown]
# # hata kontrolü
# teklik çiftlik durumuna göre hata kontrolü yapacağız. 1'lerin sayısı tek ise bu sayı tek, aksinde de çift. 7 bitlik bir sayı göndereceğiz tek giden bir sayı eğer çift olarak gözüküyor ise 8. biti bunu düzeltmek için kullanacağız. Bunlara:
# 1. Tek eşlik denetimi (odd parity check)
# 2. Çift eşlik denetimi (even parity check)
